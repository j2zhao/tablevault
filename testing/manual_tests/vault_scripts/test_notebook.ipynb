# %% [markdown]
# # Basic Tests

# %%
from ml_vault import ml_vault 
import random

# %%
vault = ml_vault.Vault("jinjin", "test2")

# %%
vault2 = ml_vault.Vault("jinjin", "test2") # vault2 = ml_vault.Vault("jinjin2", "test2")
# Out:
# ---[ ML_Vault Record ]---
# ---[ ML_Vault Record ]---

# %%
vault is vault2
# Out:
# ---[ ML_Vault Record ]---
# True
# ---[ ML_Vault Record ]---

# %% [markdown]
# # Test Artifact Creation

# %%
vault.create_file_list("file_test")
# Out:
# ---[ ML_Vault Record ]---
# ---[ ML_Vault Record ]---

# %%
vault.create_document_list("doc_test")
# Out:
# ---[ ML_Vault Record ]---
# ---[ ML_Vault Record ]---

# %%
vault.create_embedding_list("emb_test", 16)
# Out:
# ---[ ML_Vault Record ]---
# ---[ ML_Vault Record ]---

# %%
vault.create_record_list("record_test", ['test'])
# Out:
# ---[ ML_Vault Record ]---
# ---[ ML_Vault Record ]---

# %% [markdown]
# # Add Data

# %%
vault.append_file("file_test", "test_location")
# Out:
# ---[ ML_Vault Record ]---
# ---[ ML_Vault Record ]---

# %%
vault.append_file("file_test", "test_location_2")
# Out:
# ---[ ML_Vault Record ]---
# ---[ ML_Vault Record ]---

# %%
vault.append_document("doc_test", "test_location")
# Out:
# ---[ ML_Vault Record ]---
# ---[ ML_Vault Record ]---

# %%
vault.append_document("doc_test", "test_location", input_artifacts= {"file_test":[0, 1]})
# Out:
# ---[ ML_Vault Record ]---
# ---[ ML_Vault Record ]---

# %%
vault.append_record("record_test", {"test": 1})
# Out:
# ---[ ML_Vault Record ]---
# ---[ ML_Vault Record ]---

# %%
for i in range(15):
    nums = [random.random() for _ in range(16)]
    vault.append_embedding("emb_test", nums)
# Out:
# ---[ ML_Vault Record ]---
# ---[ ML_Vault Record ]---

# %%
nums = [random.random() for _ in range(1024)]
vault.create_description("TESTING COLLECTION", "emb_test", nums)
# Out:
# ---[ ML_Vault Record ]---
# ---[ ML_Vault Record ]---

# %%
vault.query_item_content("file_test")
# Out:
# ---[ ML_Vault Record ]---
# ['test_location', 'test_location_2']
# ---[ ML_Vault Record ]---

# %%
vault.query_item_content("emb_test", 0, 3)
# Out:
# ---[ ML_Vault Record ]---
# [[0.2870917328639925,
#   0.3171760398645507,
#   0.6150693345069356,
#   0.5684948249972803,
#   0.3251253807699652,
#   0.9718347497734171,
#   0.7219424651531381,
#   0.5663430404336741,
#   0.6338550218258019,
#   0.6686497809248115,
#   0.7858006623767494,
#   0.2397873957847647,
#   0.4178541869055772,
#   0.6447835877706934,
#   0.5239579442942033,
#   0.48392587314186064],
#  [0.47164206732769887,
#   0.637052847183126,
#   0.9301443424071282,
#   0.13568176840291202,
#   0.7008435970794715,
#   0.3730064848643382,
#   0.8491222172362587,
#   0.32810431726109024,
#   0.35297829972216677,
#   0.22788950772280314,
#   0.19161731195003529,
#   0.6901897665238541,
#   0.11184720475857346,
#   0.9289102111467941,
#   0.7343920291753218,
#   0.1673078768245404],
#  [0.2949949246459266,
#   0.32695901576343267,
#   0.8596708892815208,
#   0.4974919495149557,
#   0.8241617644069407,
#   0.7800018635709994,
#   0.9147382148834526,
#   0.2257005771476055,
# ...

# %%
vault.query_item_content("test2")
# Out:
# ---[ ML_Vault Record ]---
# [{'text': 'vault2 = ml_vault.Vault("jinjin", "test2") # vault2 = ml_vault.Vault("jinjin2", "test2")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 0},
#  {'text': 'vault is vault2',
#   'status': 'complete',
#   'error': '',
#   'start_position': 88},
#  {'text': 'vault.create_file_list("file_test")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 103},
#  {'text': 'vault.create_document_list("doc_test")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 138},
#  {'text': 'vault.create_embedding_list("emb_test", 16)',
#   'status': 'complete',
#   'error': '',
#   'start_position': 176},
#  {'text': 'vault.create_record_list("record_test", [\'test\'])',
#   'status': 'complete',
#   'error': '',
#   'start_position': 219},
#  {'text': 'vault.append_file("file_test", "test_location")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 268},
# ...

# %%
vault.query_session_item("test2")
# Out:
# ---[ ML_Vault Record ]---
# [{'name': 'doc_test', 'start_position': None, 'end_position': None},
#  {'name': 'doc_test', 'start_position': 0, 'end_position': 26},
#  {'name': 'emb_test', 'start_position': None, 'end_position': None},
#  {'name': 'emb_test', 'start_position': 0, 'end_position': 15},
#  {'name': 'emb_test_BASE_DESCRIPT',
#   'start_position': None,
#   'end_position': None},
#  {'name': 'file_test', 'start_position': None, 'end_position': None},
#  {'name': 'file_test', 'start_position': 0, 'end_position': 2},
#  {'name': 'record_test', 'start_position': None, 'end_position': None},
#  {'name': 'record_test', 'start_position': 0, 'end_position': 1}]
# ---[ ML_Vault Record ]---

# %%
vault.query_item_child("file_test")
# Out:
# ---[ ML_Vault Record ]---
# [[13, 26, 'document', 'doc_test', 13, 26]]
# ---[ ML_Vault Record ]---

# %% [markdown]
# # Test Deletion

# %%
vault.delete_list("file_test")
# Out:
# ---[ ML_Vault Record ]---
# {'rootId': 'file_list/file_test', 'rootKey': 'file_test', '@rootCol': 'file_list', '@childCol': 'file', 'sessionCol': 'session_list', 'sessionKey': 'test2', 'sessionIndex': 18, 'ts': 64, 'edgeKey': '64'}
# {'rootId': 'file_list/file_test', 'session_id': 'session_list/test2', 'childCount': 2, 'removed': {'session_parent_edge': 2, 'dependency_edge': 0, 'children': 2, 'parent_edge': 2}, 'updated': {'root': 1}, 'inserted': {'deleted_session_parent_edge': 1}}
# ---[ ML_Vault Record ]---
