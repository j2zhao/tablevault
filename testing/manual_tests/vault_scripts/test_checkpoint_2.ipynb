# %%
from ml_vault import ml_vault 

vault = ml_vault.Vault("jinjin", "test2", new_arango_db=False)

# %%
vault.query_item_list("test2")
# Out:
# ---[ ML_Vault Record ]---
# {'_key': 'test2',
#  '_id': 'session_list/test2',
#  '_rev': '_l_xDalW--_',
#  'creator_user_id': 'jinjin',
#  'deleted': -1,
#  'execution_type': 'notebook',
#  'interrupt_action': '',
#  'interrupt_request': '',
#  'length': 30,
#  'n_items': 1,
#  'name': 'test2',
#  'pid': 47747,
#  'session_index': 0,
#  'session_name': '',
#  'timestamp': 2}
# ---[ ML_Vault Record ]---

# %%
vault.checkpoint_execution()
# Out:
# ---[ ML_Vault Record ]---
# ---[ ML_Vault Record ]---
