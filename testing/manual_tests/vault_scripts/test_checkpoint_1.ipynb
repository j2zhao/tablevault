# %%
from ml_vault import ml_vault 

vault = ml_vault.Vault("jinjin", "test", new_arango_db=True)

# %%
vault.pause_execution(process_name = "test2")

# %%
# !ps -o pid,stat,comm -p 47747
# Out:
# ---[ ML_Vault Record ]---
#   PID STAT COMM
# 47747 Ss   /Users/jinjinzhao/miniconda3/envs/mlvault/bin/python
# ---[ ML_Vault Record ]---

# %%
vault.stop_execution(process_name = "test2")

# %%
vault.resume_execution(process_name = "test2")
