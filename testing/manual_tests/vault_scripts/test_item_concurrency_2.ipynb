# %%
from ml_vault import ml_vault 

vault = ml_vault.Vault("jinjin", "test1", new_arango_db=True)

# %%
vault.create_file_list("file_test")
# Out:
# LOCK ARTIFACT: test1
# {'_key': 'test1', '_id': 'artifacts/test1', '_rev': '_l_xZ8eK---', 'name': 'test1', 'collection': 'session_list', 'timestamp': 1, 'version': 1770010704.387485}
# {'2': ['start', 1770010705.033138, []]}
# {'_id': 'artifacts/test1', '_key': 'test1', '_rev': '_l_xZ9HG---', '_old_rev': '_l_xZ8eK---'}
# HELLLLLO
#
# ---[ ML_Vault Record ]---
# LOCK ARTIFACT: test1
# {'_key': 'test1', '_id': 'artifacts/test1', '_rev': '_l_xZ9Ia---', 'name': 'test1', 'collection': 'session_list', 'timestamp': 2, 'version': 1770010705.0624}
# {'4': ['start', 1770010705.102149, ['session_add_code_end', 'test1', 0, '']]}
# {'_id': 'artifacts/test1', '_key': 'test1', '_rev': '_l_xZ9La---', '_old_rev': '_l_xZ9Ia---'}
# ---[ ML_Vault Record ]---

# %%
vault.append_file("file_test", "test_location")
# Out:
# LOCK ARTIFACT: test1
# {'_key': 'test1', '_id': 'artifacts/test1', '_rev': '_l_xZ9La---', 'name': 'test1', 'collection': 'session_list', 'timestamp': 4, 'version': 1770010705.111538}
# {'5': ['start', 1770010707.1692748, []]}
# {'_id': 'artifacts/test1', '_key': 'test1', '_rev': '_l_xa_M6---', '_old_rev': '_l_xZ9La---'}
# HELLLLLO
#
# ---[ ML_Vault Record ]---
# LOCK ARTIFACT: file_test
# {'_key': 'file_test', '_id': 'artifacts/file_test', '_rev': '_l_xZ9K----', 'name': 'file_test', 'collection': 'file_list', 'timestamp': 3, 'version': 1770010705.087723}
# {'6': ['start', 1770010707.2225668, []]}
# {'_id': 'artifacts/file_test', '_key': 'file_test', '_rev': '_l_xa_QC---', '_old_rev': '_l_xZ9K----'}
# HELLLLLO
# HELLO TESTING
# LOCK ARTIFACT: test1
# {'_key': 'test1', '_id': 'artifacts/test1', '_rev': '_l_xa_OW---', 'name': 'test1', 'collection': 'session_list', 'timestamp': 5, 'version': 1770010707.205872}
# {'15': ['start', 1770010767.2817311, ['session_add_code_end', 'test1', 1, '']]}
# {'_id': 'artifacts/test1', '_key': 'test1', '_rev': '_l_xa55q---', '_old_rev': '_l_xa_OW---'}
# ---[ ML_Vault Record ]---
