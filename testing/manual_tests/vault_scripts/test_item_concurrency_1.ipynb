# %%
from ml_vault import ml_vault 

vault = ml_vault.Vault("jinjin", "test5", new_arango_db=False)
# modified code for pausing (would use pytest later for best practices)

# %%
vault.query_item_list("test1")
# Out:
# LOCK ARTIFACT: test5
# {'_key': 'test5', '_id': 'artifacts/test5', '_rev': '_l_xaLfu---', 'name': 'test5', 'collection': 'session_list', 'timestamp': 7, 'version': 1770010719.771966}
# {'6': ['update', 1770010707.240159, ['append_artifact', 'file_test', 'file', {}, 'test1', 1, 0, 0]], '8': ['start', 1770010720.41857, []]}
# {'_id': 'artifacts/test5', '_key': 'test5', '_rev': '_l_xaMIy---', '_old_rev': '_l_xaLfu---'}
# HELLLLLO
#
# ---[ ML_Vault Record ]---
# {'_key': 'test1',
#  '_id': 'session_list/test1',
#  '_rev': '_l_xa_OW--_',
#  'creator_user_id': 'jinjin',
#  'deleted': -1,
#  'execution_type': 'notebook',
#  'interrupt_action': '',
#  'interrupt_request': '',
#  'length': 83,
#  'n_items': 2,
#  'name': 'test1',
#  'pid': 54035,
#  'session_index': 0,
#  'session_name': '',
#  'timestamp': 1}
# LOCK ARTIFACT: test5
# {'_key': 'test5', '_id': 'artifacts/test5', '_rev': '_l_xaMJ6---', 'name': 'test5', 'collection': 'session_list', 'timestamp': 8, 'version': 1770010720.447542}
# ...

# %%
vault.query_item_content("test1", index=0)
# Out:
# LOCK ARTIFACT: test5
# {'_key': 'test5', '_id': 'artifacts/test5', '_rev': '_l_xaML2---', 'name': 'test5', 'collection': 'session_list', 'timestamp': 9, 'version': 1770010720.4778519}
# {'6': ['update', 1770010707.240159, ['append_artifact', 'file_test', 'file', {}, 'test1', 1, 0, 0]], '10': ['start', 1770010725.043446, []]}
# {'_id': 'artifacts/test5', '_key': 'test5', '_rev': '_l_xaQp2---', '_old_rev': '_l_xaML2---'}
# HELLLLLO
#
# ---[ ML_Vault Record ]---
# hello
# session
# {'text': 'vault.create_file_list("file_test")\n',
#  'status': 'complete',
#  'error': '',
#  'start_position': 0,
#  'index': 0}
# LOCK ARTIFACT: test5
# {'_key': 'test5', '_id': 'artifacts/test5', '_rev': '_l_xaQra---', 'name': 'test5', 'collection': 'session_list', 'timestamp': 10, 'version': 1770010725.078464}
# {'6': ['update', 1770010707.240159, ['append_artifact', 'file_test', 'file', {}, 'test1', 1, 0, 0]], '11': ['start', 1770010725.1062799, ['session_add_code_end', 'test5', 1, '']]}
# ...

# %%
vault.append_file("file_test", "test_location_2")
# Out:
# LOCK ARTIFACT: test5
# {'_key': 'test5', '_id': 'artifacts/test5', '_rev': '_l_xaYW2---', 'name': 'test5', 'collection': 'session_list', 'timestamp': 14, 'version': 1770010732.943383}
# {'16': ['start', 1770010795.6562262, []]}
# {'_id': 'artifacts/test5', '_key': 'test5', '_rev': '_l_xbVnO---', '_old_rev': '_l_xaYW2---'}
# HELLLLLO
#
# ---[ ML_Vault Record ]---
# LOCK ARTIFACT: file_test
# {'_key': 'file_test', '_id': 'artifacts/file_test', '_rev': '_l_xa54C---', 'name': 'file_test', 'collection': 'file_list', 'timestamp': 6, 'version': 1770010767.2637591}
# {'17': ['start', 1770010795.704224, []]}
# {'_id': 'artifacts/file_test', '_key': 'file_test', '_rev': '_l_xbVq----', '_old_rev': '_l_xa54C---'}
# HELLLLLO
# LOCK ARTIFACT: test5
# {'_key': 'test5', '_id': 'artifacts/test5', '_rev': '_l_xbVom---', 'name': 'test5', 'collection': 'session_list', 'timestamp': 16, 'version': 1770010795.688511}
# {'18': ['start', 1770010795.744017, ['session_add_code_end', 'test5', 3, '']]}
# ...
