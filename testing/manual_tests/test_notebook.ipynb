# %% [markdown]
# # Basic Tests

# %%
from ml_vault import ml_vault 
import random

# %%
vault = ml_vault.Vault("jinjin", "test2")

# %%
print('hello')
# Out:
# ---[ Cell Begin Record ]---
# hello
# ---[ Cell End Record ]---

# %%
vault.create_file_list("file_test")
# Out:
# ---[ Cell Begin Record ]---
# ---[ Cell End Record ]---

# %%
vault.create_document_list("doc_test")
# Out:
# ---[ Cell Begin Record ]---
# ---[ Cell End Record ]---

# %%
vault.create_embedding_list("emb_test", 16)
# Out:
# ---[ Cell Begin Record ]---
# ---[ Cell End Record ]---

# %%
vault.create_record_list("record_test", ['test'])
# Out:
# ---[ Cell Begin Record ]---
# ---[ Cell End Record ]---

# %% [markdown]
# # Add Data

# %%
vault.append_file("file_test", "test_location")
# Out:
# ---[ Cell Begin Record ]---
# {'location': 'test_location', 'index': 0, 'start_position': 0, 'end_position': 1, '_key': 'file_test_0', 'name': 'file_test', 'session_name': 'test2', 'session_index': 5, 'timestamp': 17}
# ---[ Cell End Record ]---

# %%
vault.append_file("file_test", "test_location_2")
# Out:
# ---[ Cell Begin Record ]---
# {'location': 'test_location_2', 'index': 1, 'start_position': 1, 'end_position': 2, '_key': 'file_test_1', 'name': 'file_test', 'session_name': 'test2', 'session_index': 6, 'timestamp': 20}
# ---[ Cell End Record ]---

# %%
vault.append_document("doc_test", "test_location")
# Out:
# ---[ Cell Begin Record ]---
# {'text': 'test_location', 'index': 0, 'start_position': 0, 'end_position': 13, '_key': 'doc_test_0', 'name': 'doc_test', 'session_name': 'test2', 'session_index': 7, 'timestamp': 23}
# ---[ Cell End Record ]---

# %%
vault.append_document("doc_test", "test_location", input_artifacts= {"file_test":[0, 1]})
# Out:
# ---[ Cell Begin Record ]---
# {'text': 'test_location', 'index': 1, 'start_position': 13, 'end_position': 26, '_key': 'doc_test_1', 'name': 'doc_test', 'session_name': 'test2', 'session_index': 8, 'timestamp': 26}
# ---[ Cell End Record ]---

# %%
vault.append_record("record_test", {"test": 1})
# Out:
# ---[ Cell Begin Record ]---
# {'data': {'test': 1}, 'data_text': "{'test': 1}", 'column_names': ['test'], 'index': 0, 'start_position': 0, 'end_position': 1, '_key': 'record_test_0', 'name': 'record_test', 'session_name': 'test2', 'session_index': 9, 'timestamp': 29}
# ---[ Cell End Record ]---

# %%
for i in range(15):
    nums = [random.random() for _ in range(16)]
    vault.append_embedding("emb_test", nums)
# Out:
# ---[ Cell Begin Record ]---
# {'embedding_16': [0.4704657493881006, 0.7262488428327096, 0.47107760700025847, 0.9302186674075069, 0.26215996135925645, 0.0775577014147153, 0.6234089215199193, 0.5884100197644794, 0.5172888450520666, 0.18685532530655202, 0.25434331074289074, 0.2925163685853298, 0.8444401180131905, 0.643707489281836, 0.6945903364820868, 0.6390678877087663], 'index': 0, 'start_position': 0, 'end_position': 1, '_key': 'emb_test_0', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 32}
# hello
# (1, 0)
# {'embedding_16': [0.4841861895538182, 0.8053482013786348, 0.566377035100327, 0.0903748182349029, 0.6231098495982245, 0.6477113153703352, 0.4459517106430191, 0.16681162673874383, 0.9721397163104317, 0.08286700911144096, 0.21470727272595003, 0.011913960654649558, 0.908773058716893, 0.5687486895420336, 0.8550454760202024, 0.6745022203974942], 'index': 1, 'start_position': 1, 'end_position': 2, '_key': 'emb_test_1', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 33}
# hello
# (2, 0)
# {'embedding_16': [0.26555423842061887, 0.9299904654946965, 0.2554139486150364, 0.48596873357076487, 0.39918258992364597, 0.7953892528882808, 0.7332746631502747, 0.5662402336628993, 0.4747296155740772, 0.8054221260885741, 0.8509861642528653, 0.3475943466238418, 0.8871927160527975, 0.9016170592092585, 0.9316289496209611, 0.9329954167331683], 'index': 2, 'start_position': 2, 'end_position': 3, '_key': 'emb_test_2', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp':
 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 41}
# hello
# (10, 0)
# {'embedding_16': [0.08019154151422303, 0.37790485490924297, 0.2868694457503721, 0.06739225445567743, 0.9085640823848506, 0.8350472533190313, 0.15888642574347533, 0.13362805912106057, 0.36488736364388474, 0.8641414004725305, 0.5663191361183411, 0.03183569303957168, 0.16072384886351976, 0.25171196933103046, 0.7065773436276649, 0.20275119862229884], 'index': 10, 'start_position': 10, 'end_position': 11, '_key': 'emb_test_10', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 42}
# hello
# (11, 0)
# HELLLO
# {'embedding_16': [0.5719138701632864, 0.7020202706973285, 0.5706133761208012, 0.7425166959739797, 0.42721047604624396, 0.3937687052633818, 0.5420260813788443, 0.3585801832636307, 0.2037262035126981, 0.045803933724727575, 0.16039465050384183, 0.8804143580111846, 0.9835640834455843, 0.7993211054358053, 0.028878158449997415, 0.23378570070455684], 'index': 11, 'start_position': 11, 'end_position': 12, '_key': 'emb_test_11', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 43}
# hello
# (12, 11)
# {'embedding_16': [0.6496155003939663, 0.4212007456508652, 0.5262170367114641, 0.43284786517095686, 0.22656305631109985, 0.629121186541027, 0.6951928198897934, 0.19421235223629263, 0.7154381703714028, 0.7827928502887652, 0.522679843041949, 0.4467343402672266, 0.7108061140268583, 0.0852533110706023, 0.23725750841017312, 0.8912886965816015], 'index': 12, 'start_position': 12, 'end_position': 13, '_key': 'emb_test_12', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 44}
# hello
# (13, 11)
# {'embedding_16': [0.08523293384618058, 0.8941457970202166, 0.44794751547156053, 0.3801864763483622, 0.18983162094621087, 0.6017288467684371, 0.15517460125028149, 0.08694467275545359, 0.436705851241741, 0.5716453627319322, 0.24439162370256817, 0.44909194959960164, 0.6449185436882328, 0.8307356760677281, 0.03194014078522378, 0.6045876823928862], 'index': 13, 'start_position': 13, 'end_position': 14, '_key': 'emb_test_13', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 45}
# hello
# (14, 11)
# {'embedding_16': [0.2710629910126424, 0.296705445266493, 0.49841329031576687, 0.37734872483495707, 0.7802224314261907, 0.45261618527148606, 0.09085414500157818, 0.23859340686847186, 0.14565890629171163, 0.09222396835285729, 0.900776729261412, 0.14862074969771555, 0.8267085941006431, 0.9134147069895076, 0.5549217753446611, 0.33874490370253807], 'index': 14, 'start_position': 14, 'end_position': 15, '_key': 'emb_test_14', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 46}
# hello
# (15, 11)
# ---[ Cell End Record ]---

# %%
nums = [random.random() for _ in range(1024)]
vault.create_description("TESTING COLLECTION", "emb_test", nums)
# Out:
# ---[ Cell Begin Record ]---
# ---[ Cell End Record ]---

# %%
vault.query_item_content("file_test")
# Out:
# ---[ Cell Begin Record ]---
# ['test_location', 'test_location_2']
# ---[ Cell End Record ]---

# %%
vault.query_item_content("emb_test", 0, 3)
# Out:
# ---[ Cell Begin Record ]---
# [[0.4704657493881006,
#   0.7262488428327096,
#   0.47107760700025847,
#   0.9302186674075069,
#   0.26215996135925645,
#   0.0775577014147153,
#   0.6234089215199193,
#   0.5884100197644794,
#   0.5172888450520666,
#   0.18685532530655202,
#   0.25434331074289074,
#   0.2925163685853298,
#   0.8444401180131905,
#   0.643707489281836,
#   0.6945903364820868,
#   0.6390678877087663],
#  [0.4841861895538182,
#   0.8053482013786348,
#   0.566377035100327,
#   0.0903748182349029,
#   0.6231098495982245,
#   0.6477113153703352,
#   0.4459517106430191,
#   0.16681162673874383,
#   0.9721397163104317,
#   0.08286700911144096,
#   0.21470727272595003,
#   0.011913960654649558,
#   0.908773058716893,
#   0.5687486895420336,
#   0.8550454760202024,
#   0.6745022203974942],
#  [0.26555423842061887,
#   0.9299904654946965,
#   0.2554139486150364,
#   0.48596873357076487,
#   0.39918258992364597,
#   0.7953892528882808,
#   0.7332746631502747,
#   0.5662402336628993,
#   0.4747296155740772,
#   0.8054221260885741,
#   0.8509861642528653,
#   0.3475943466238418,
#   0.8871927160527975,
#   0.9016170592092585,
#   0.9316289496209611,
#   0.9329954167331683]]
# ---[ Cell End Record ]---

# %%
vault.query_item_content("test2")
# Out:
# ---[ Cell Begin Record ]---
# [{'text': "print('hello')",
#   'status': 'complete',
#   'error': '',
#   'start_position': 0},
#  {'text': 'vault.create_file_list("file_test")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 14},
#  {'text': 'vault.create_document_list("doc_test")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 49},
#  {'text': 'vault.create_embedding_list("emb_test", 16)',
#   'status': 'complete',
#   'error': '',
#   'start_position': 87},
#  {'text': 'vault.create_record_list("record_test", [\'test\'])',
#   'status': 'complete',
#   'error': '',
#   'start_position': 130},
#  {'text': 'vault.append_file("file_test", "test_location")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 179},
#  {'text': 'vault.append_file("file_test", "test_location_2")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 226},
#  {'text': 'vault.append_document("doc_test", "test_location")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 275},
#  {'text': 'vault.append_document("doc_test", "test_location", input_artifacts= {"file_test":[0, 1]})',
#   'status': 'complete',
#   'error': '',
#   'start_position': 325},
#  {'text': 'vault.append_record("record_test", {"test": 1})',
#   'status': 'complete',
#   'error': '',
#   'start_position': 414},
#  {'text': 'for i in range(15):\n    nums = [random.random() for _ in range(16)]\n    vault.append_embedding("emb_test", nums)',
#   'status': 'complete',
#   'error': '',
#   'start_position': 461},
#  {'text': 'nums = [random.random() for _ in range(1024)]\nvault.create_description("TESTING COLLECTION", "emb_test", nums)',
#   'status': 'complete',
#   'error': '',
#   'start_position': 573},
#  {'text': 'vault.query_item_content("file_test")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 683},
#  {'text': 'vault.query_item_content("emb_test", 0, 3)',
#   'status': 'complete',
#   'error': '',
#   'start_position': 720},
#  {'text': 'vault.query_item_content("test2")',
#   'status': 'start',
#   'error': '',
#   'start_position': 762}]
# ---[ Cell End Record ]---

# %%
vault.query_session_item("test2")
# Out:
# ---[ Cell Begin Record ]---
# [{'name': 'doc_test', 'start_position': None, 'end_position': None},
#  {'name': 'doc_test', 'start_position': 0, 'end_position': 26},
#  {'name': 'emb_test', 'start_position': None, 'end_position': None},
#  {'name': 'emb_test', 'start_position': 0, 'end_position': 15},
#  {'name': 'emb_test_BASE_DESCRIPT',
#   'start_position': None,
#   'end_position': None},
#  {'name': 'file_test', 'start_position': None, 'end_position': None},
#  {'name': 'file_test', 'start_position': 0, 'end_position': 2},
#  {'name': 'record_test', 'start_position': None, 'end_position': None},
#  {'name': 'record_test', 'start_position': 0, 'end_position': 1}]
# ---[ Cell End Record ]---

# %%
vault.query_item_child("file_test")
# Out:
# ---[ Cell Begin Record ]---
# [[0, 1, 'document', 'doc_test', 13, 26]]
# ---[ Cell End Record ]---
