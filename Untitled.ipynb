# %%
from arango import ArangoClient


client = ArangoClient(hosts="http://localhost:8529")

db = client.db("ml_vault", username="mlvault_user", password="mlvault_password")

# %%
metadata = db.collection("embedding")

# %%
col = db.collection("embedding")
for idx in col.indexes():
    print(idx)
# Out:
# {'id': '0', 'fields': ['_key'], 'type': 'primary', 'name': 'primary', 'sparse': False, 'unique': True, 'selectivity': 1}
# {'id': '780', 'fields': ['embedding_16'], 'type': 'vector', 'name': 'embedding_16_idx', 'sparse': False, 'unique': False}

# %%
docs
# Out:
# [{'_key': 'test2_0',
#   '_id': 'session/test2_0',
#   '_rev': '_k7i2EEC---',
#   'name': 'test2_0',
#   'index': 0,
#   'timestamp': 2,
#   'start_position': 0,
#   'end_position': 14,
#   'text': "print('hello')",
#   'status': 'start',
#   'error': ''}]
