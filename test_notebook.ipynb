# %% [markdown]
# # Basic Tests

# %%
from ml_vault import ml_vault 
import random

# %%
vault = ml_vault.Vault("jinjin", "test2")

# %%
print('hello')
# Out:
# ---[ Cell Begin Record ]---
# hello
# ---[ Cell End Record ]---

# %%
vault.create_file_list("file_test")
# Out:
# ---[ Cell Begin Record ]---
# ---[ Cell End Record ]---

# %%
vault.create_document_list("doc_test")
# Out:
# ---[ Cell Begin Record ]---
# ---[ Cell End Record ]---

# %%
vault.create_embedding_list("emb_test", 16)
# Out:
# ---[ Cell Begin Record ]---
# ---[ Cell End Record ]---

# %%
vault.create_record_list("record_test", ['test'])
# Out:
# ---[ Cell Begin Record ]---
# ---[ Cell End Record ]---

# %% [markdown]
# # Add Data

# %%
vault.append_file("file_test", "test_location")
# Out:
# ---[ Cell Begin Record ]---
# {'location': 'test_location', 'index': 0, 'start_position': 0, 'end_position': 1, '_key': 'file_test_0', 'name': 'file_test', 'session_name': 'test2', 'session_index': 5, 'timestamp': 17}
# ---[ Cell End Record ]---

# %%
vault.append_file("file_test", "test_location_2")
# Out:
# ---[ Cell Begin Record ]---
# {'location': 'test_location_2', 'index': 1, 'start_position': 1, 'end_position': 2, '_key': 'file_test_1', 'name': 'file_test', 'session_name': 'test2', 'session_index': 6, 'timestamp': 20}
# ---[ Cell End Record ]---

# %%
vault.append_document("doc_test", "test_location")
# Out:
# ---[ Cell Begin Record ]---
# {'text': 'test_location', 'index': 0, 'start_position': 0, 'end_position': 13, '_key': 'doc_test_0', 'name': 'doc_test', 'session_name': 'test2', 'session_index': 7, 'timestamp': 23}
# ---[ Cell End Record ]---

# %%
vault.append_document("doc_test", "test_location", input_artifacts= {"file_test":[0, 1]})
# Out:
# ---[ Cell Begin Record ]---
# {'text': 'test_location', 'index': 1, 'start_position': 13, 'end_position': 26, '_key': 'doc_test_1', 'name': 'doc_test', 'session_name': 'test2', 'session_index': 8, 'timestamp': 26}
# ---[ Cell End Record ]---

# %%
vault.append_record("record_test", {"test": 1})
# Out:
# ---[ Cell Begin Record ]---
# {'data': {'test': 1}, 'data_text': "{'test': 1}", 'column_names': ['test'], 'index': 0, 'start_position': 0, 'end_position': 1, '_key': 'record_test_0', 'name': 'record_test', 'session_name': 'test2', 'session_index': 9, 'timestamp': 29}
# ---[ Cell End Record ]---

# %%
for i in range(15):
    nums = [random.random() for _ in range(16)]
    vault.append_embedding("emb_test", nums)
# Out:
# ---[ Cell Begin Record ]---
# {'embedding_16': [0.6061327641813371, 0.8381040811845148, 0.5454518431134977, 0.40665389176973343, 0.1404014302092098, 0.989112745272864, 0.9289567594444114, 0.1620858056344724, 0.06849571526526033, 0.2786344242818274, 0.8676181269589689, 0.06084028950974907, 0.5854064251777089, 0.2719033379447112, 0.10157057378024348, 0.0663423973810705], 'index': 0, 'start_position': 0, 'end_position': 1, '_key': 'emb_test_0', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 32}
# hello
# (1, 0)
# {'embedding_16': [0.8370858704625854, 0.5911339165548026, 0.418433311708869, 0.5256081501765336, 0.35982134911582175, 0.12381851445850056, 0.12698695549777783, 0.22600610046260394, 0.28733575541832745, 0.1056385195317433, 0.34771454326607554, 0.7273578298459825, 0.21769522710864675, 0.533901240897472, 0.3779620109119145, 0.6474081874284316], 'index': 1, 'start_position': 1, 'end_position': 2, '_key': 'emb_test_1', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 33}
# hello
# (2, 0)
# {'embedding_16': [0.28076023706289743, 0.006831946259182042, 0.7423074135160525, 0.42205397310116066, 0.7704295588490992, 0.19307563944616835, 0.156441078273294, 0.2504677793900921, 0.7620034801366793, 0.6731199400951927, 0.5566941021671787, 0.627271667586946, 0.323366399746418, 0.28799040687492183, 0.03749099012125545, 0.2731361052468999], 'index': 2, 'start_position': 2, 'end_position': 3, '_key': 'emb_test_2', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp':
 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 41}
# hello
# (10, 0)
# {'embedding_16': [0.9631536236855304, 0.1852189012544596, 0.9504831302734441, 0.3370313570458612, 0.8002931394845374, 0.14572925764153277, 0.8660073928582545, 0.0708230026985851, 0.8650066503291183, 0.02982046022406104, 0.7754873036267015, 0.9422445769164156, 0.9043021463856626, 0.026414610060879418, 0.9959990559509033, 0.8590552534716891], 'index': 10, 'start_position': 10, 'end_position': 11, '_key': 'emb_test_10', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 42}
# hello
# (11, 0)
# HELLLO
# {'embedding_16': [0.6752102145631119, 0.12145744459346519, 0.2676905527407393, 0.1890884910452103, 0.934480479698057, 0.32778511934838006, 0.5782673550794939, 0.2975356668004736, 0.9700768309963159, 0.7103118527114362, 0.39183827669061366, 0.5901455715554671, 0.8891925966678162, 0.930687640244333, 0.13211037986559593, 0.9383438587932468], 'index': 11, 'start_position': 11, 'end_position': 12, '_key': 'emb_test_11', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 43}
# hello
# (12, 11)
# {'embedding_16': [0.7366979751758256, 0.43232839308479376, 0.22096442682296902, 0.4012192754923052, 0.32520088998181684, 0.09928971745030357, 0.30337311435997405, 0.536928635541337, 0.234456126105678, 0.11717396091078347, 0.017869388486166704, 0.08781835299589014, 0.4719186006873004, 0.7652539214458016, 0.16784218417857788, 0.15182659009900745], 'index': 12, 'start_position': 12, 'end_position': 13, '_key': 'emb_test_12', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 44}
# hello
# (13, 11)
# {'embedding_16': [0.86418507975073, 0.8978836959927781, 0.6107647641527509, 0.36704691657167465, 0.42669780831657245, 0.18695720307808805, 0.005406359042428144, 0.3667605302371979, 0.7103983394474941, 0.6165416400962207, 0.3731584848692263, 0.2154499639543157, 0.816242005685935, 0.8071340004032278, 0.21635798662522288, 0.22066648538270606], 'index': 13, 'start_position': 13, 'end_position': 14, '_key': 'emb_test_13', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 45}
# hello
# (14, 11)
# {'embedding_16': [0.08936723614706898, 0.8682128198338074, 0.6185000429718296, 0.24024917149058078, 0.5898423239036851, 0.4377894310148155, 0.15748034976369585, 0.7739361395243574, 0.6437798213211671, 0.3425812308746543, 0.09943220450869616, 0.7782336480964226, 0.5880007436930418, 0.1405864947544614, 0.17838734219353447, 0.7636410621942403], 'index': 14, 'start_position': 14, 'end_position': 15, '_key': 'emb_test_14', 'name': 'emb_test', 'session_name': 'test2', 'session_index': 10, 'timestamp': 46}
# hello
# (15, 11)
# ---[ Cell End Record ]---

# %%
nums = [random.random() for _ in range(1024)]
vault.create_description("TESTING COLLECTION", "emb_test", nums)
# Out:
# ---[ Cell Begin Record ]---
# ---[ Cell End Record ]---

# %%
vault.query_item_content("file_test")
# Out:
# ---[ Cell Begin Record ]---
# ['test_location', 'test_location_2']
# ---[ Cell End Record ]---

# %%
vault.query_item_content("emb_test", 0, 3)
# Out:
# ---[ Cell Begin Record ]---
# [[0.6061327641813371,
#   0.8381040811845148,
#   0.5454518431134977,
#   0.40665389176973343,
#   0.1404014302092098,
#   0.989112745272864,
#   0.9289567594444114,
#   0.1620858056344724,
#   0.06849571526526033,
#   0.2786344242818274,
#   0.8676181269589689,
#   0.06084028950974907,
#   0.5854064251777089,
#   0.2719033379447112,
#   0.10157057378024348,
#   0.0663423973810705],
#  [0.8370858704625854,
#   0.5911339165548026,
#   0.418433311708869,
#   0.5256081501765336,
#   0.35982134911582175,
#   0.12381851445850056,
#   0.12698695549777783,
#   0.22600610046260394,
#   0.28733575541832745,
#   0.1056385195317433,
#   0.34771454326607554,
#   0.7273578298459825,
#   0.21769522710864675,
#   0.533901240897472,
#   0.3779620109119145,
#   0.6474081874284316],
#  [0.28076023706289743,
#   0.006831946259182042,
#   0.7423074135160525,
#   0.42205397310116066,
#   0.7704295588490992,
#   0.19307563944616835,
#   0.156441078273294,
#   0.2504677793900921,
#   0.7620034801366793,
#   0.6731199400951927,
#   0.5566941021671787,
#   0.627271667586946,
#   0.323366399746418,
#   0.28799040687492183,
#   0.03749099012125545,
#   0.2731361052468999]]
# ---[ Cell End Record ]---

# %%
vault.query_item_content("test2")
# Out:
# ---[ Cell Begin Record ]---
# [{'text': "print('hello')",
#   'status': 'complete',
#   'error': '',
#   'start_position': 0},
#  {'text': 'vault.create_file_list("file_test")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 14},
#  {'text': 'vault.create_document_list("doc_test")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 49},
#  {'text': 'vault.create_embedding_list("emb_test", 16)',
#   'status': 'complete',
#   'error': '',
#   'start_position': 87},
#  {'text': 'vault.create_record_list("record_test", [\'test\'])',
#   'status': 'complete',
#   'error': '',
#   'start_position': 130},
#  {'text': 'vault.append_file("file_test", "test_location")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 179},
#  {'text': 'vault.append_file("file_test", "test_location_2")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 226},
#  {'text': 'vault.append_document("doc_test", "test_location")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 275},
#  {'text': 'vault.append_document("doc_test", "test_location", input_artifacts= {"file_test":[0, 1]})',
#   'status': 'complete',
#   'error': '',
#   'start_position': 325},
#  {'text': 'vault.append_record("record_test", {"test": 1})',
#   'status': 'complete',
#   'error': '',
#   'start_position': 414},
#  {'text': 'for i in range(15):\n    nums = [random.random() for _ in range(16)]\n    vault.append_embedding("emb_test", nums)',
#   'status': 'complete',
#   'error': '',
#   'start_position': 461},
#  {'text': 'nums = [random.random() for _ in range(1024)]\nvault.create_description("TESTING COLLECTION", "emb_test", nums)',
#   'status': 'complete',
#   'error': '',
#   'start_position': 573},
#  {'text': 'vault.query_item_content("file_test")',
#   'status': 'complete',
#   'error': '',
#   'start_position': 683},
#  {'text': 'vault.query_item_content("emb_test", 0, 3)',
#   'status': 'complete',
#   'error': '',
#   'start_position': 720},
#  {'text': 'vault.query_item_content("test2")',
#   'status': 'start',
#   'error': '',
#   'start_position': 762}]
# ---[ Cell End Record ]---

# %%
vault.query_session_item("test2")
# Out:
# ---[ Cell Begin Record ]---
# [{'name': 'doc_test', 'start_position': None, 'end_position': None},
#  {'name': 'doc_test', 'start_position': 0, 'end_position': 26},
#  {'name': 'emb_test', 'start_position': None, 'end_position': None},
#  {'name': 'emb_test', 'start_position': 0, 'end_position': 15},
#  {'name': 'emb_test_BASE_DESCRIPT',
#   'start_position': None,
#   'end_position': None},
#  {'name': 'file_test', 'start_position': None, 'end_position': None},
#  {'name': 'file_test', 'start_position': 0, 'end_position': 2},
#  {'name': 'record_test', 'start_position': None, 'end_position': None},
#  {'name': 'record_test', 'start_position': 0, 'end_position': 1}]
# ---[ Cell End Record ]---

# %%
vault.query_item_children("file_test")
# Out:
# ---[ Cell Begin Record ]---
# [[0, 1, 'document', 'doc_test', 13, 26]]
# ---[ Cell End Record ]---
