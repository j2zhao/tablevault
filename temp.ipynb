# %%
import Vault

session = vault(user_id)

# %%
output = [
   {"column_name": ''},
   { ""},
]

collect = session.get_data(artifact_type, collection_name, condition) # i want the full table

collect.id = "X"
collect.collection_type = "Y"
collect.query = "Z"

# %%
for c in collecion

# %%
collection = session.create_collection("image_transfromation", description = True)

for i, img in enumerate(data):
    vector = run_model(img.data)
    collection.put(vector, deps = [data.id, i])
